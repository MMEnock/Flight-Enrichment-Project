# %%
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
from dateutil import relativedelta
import autopep8
import os
import re 
import cProfile
from typing import IO

# %%
'''
The goal of this script is to select a to be cleaned file . This is done by selecting a file index ranging from 0 . 
In this way , a user is able to choose a file of their choice for further cleaning and Data manipulation . 
'''

basePath = r"I:\Flight Enrichment Assignment"

files = ["CGN0322S", "CGN1025S"]

file_index = 0
if file_index < len(files):

    file = files[file_index]

    filepath = os.path.join(basePath, file)

    print(filepath)
else:
    print("This specific file is not available")
# Out:
# I:\Flight Enrichment Assignment\CGN1025S

# %%
def import_fs(filepath) -> IO[str]:
    '''
    Checks for a specific file path and fetches it into a data frame for further 
    data cleaning manipulation . 
    '''
    FS = pd.read_excel(filepath,
                       dtype={
                           "Days Of operations": str,
                           "Time": str,
                           "Aircraft Type": str
                       })
    return FS

# %%
def convert_timestr(fs: IO[str]) -> IO[str]:
    '''
    Corrects Time to a normal HH:MM time format and converts it a normal time representation.FS stands for flight schedule
    '''
    # Correct the Time format to HH:MM:SS

    fs["Time"] = fs["Time"].str[:2] + ":" + fs["Time"].str[2:] + ":" + "00"
    return fs

# %%
def calculate_timeaftermidnight(fs: IO[str]) -> IO[str]:
    '''
    Converts 'Time' in the format HH:MM:SS" to minutes after midnight.
    '''

    # Convert 'Time' column to datetime format, now compatible with both formats
    fs['Time'] = pd.to_datetime(fs['Time'])

    # Calculate minutes after midnight
    fs["time_aftermidnight"] = fs['Time'].dt.hour * 60 + fs['Time'].dt.minute
    return fs

# %%
def filter_stype_CJ(fs: IO[str]) -> IO[str]:
    '''
    Selects only Flight schedules whose service type is J and C. 
    '''
    # Create a boolean mask where True indicates rows where "Service type" is "J" or "C"
    mask = fs["Service type"].apply(lambda x: x == "J" or x == "C")

    # Use the mask to filter rows in FS
    return fs[mask]

# %%
def count_operatingweeklytime(fs: IO[str]) -> IO[str]:
    """
    Counts the number of times a flight operates on a weekly basis.
    """

    fs["Operating Times Per Week"] = fs['Days Of operations'].apply(
        lambda x: sum(1 for char in x if char != '0'))

    return fs

# %%
def convert_dates(fs: IO[str]) -> IO[str]:
    '''
    Converts a data range to days , this parameter comes in handy during data range weight application. 
    '''
    fs["Start Date"] = pd.to_datetime(fs["Start Date"], format="%Y%m%d")

    fs["End Date"] = pd.to_datetime(fs["End Date"], format="%Y%m%d")

    fs["Date Range"] = fs.apply(
        lambda row: row["End Date"] - row["Start Date"], axis=1).dt.days
    return fs

# %%
def reduce_numberofcolumns(fs: IO[str]) -> IO[str]:
    # List of columns to be selected
    columns = [
        "Airline_Code", "Leg Type", "Via", "Origin-Destination","Start Date","End Date",
        'Days Of operations', "Operating Times Per Week", "time_aftermidnight",
        "Date Range"
    ]

    fs = fs[columns]

    return fs

# %%
def removespaces(fs: IO[str]) -> IO[str]:
    columns_fs = [
        "Airline_Code", "Local Airport", "Leg Type", "Via",
        "Origin-Destination"
    ]
    for column in columns_fs:
        fs[column] = fs[column].apply(lambda x: x.strip())
    return fs

# %%
def import_flightschedule(file):
    '''
    In order to understand where script issues are rising from , I created an output of None indicating 
    weather a File Schedule is empty or not . 
    '''
    srcpath = os.path.join(basePath, "data_raw",
                           f"{file}.xlsx")  # stands for source path
    print("The source path is ", srcpath)
    dstpath = os.path.join(basePath, "data",
                           f"{file}.pkl")  # stands for destinaion path
    print("The destination path is", dstpath)

    fs = import_fs(srcpath)
    print("After ImportFS:", fs is None)

    fs = convert_timestr(fs)
    print("After Timestr:", fs is None)

    fs = calculate_timeaftermidnight(fs)
    print("After TimeafterMidnight:", fs is None)

    fs = filter_stype_CJ(fs)
    print("After Servicetype:", fs is None)

    fs = count_operatingweeklytime(fs)
    print("After aircrafttype:", fs is None)

    fs = convert_dates(fs)
    print("After daterange:", fs is None)

    fs = removespaces(fs)
    print("After all spaces have been removed:", fs is None)

    fs = reduce_numberofcolumns(fs)
    print("After newfs:", fs is None)
    '''
    #The file is saved in a pickle format on the provided file path . 
    '''

    fs.to_pickle(dstpath)

# %%
if __name__ == "__main__":
    import_flightschedule(file)
# Out:
# The source path is  I:\Flight Enrichment Assignment\data_raw\CGN1025S.xlsx
# The destination path is I:\Flight Enrichment Assignment\data\CGN1025S.pkl
# After ImportFS: False
# After Timestr: False
# After TimeafterMidnight: False
# After Servicetype: False
# After aircrafttype: False
# After daterange: False
# After all spaces have been removed: False
# After newfs: False

# %%
cProfile.run('import_flightschedule(file)')
# Out:
# The source path is  I:\Flight Enrichment Assignment\data_raw\CGN1025S.xlsx
# The destination path is I:\Flight Enrichment Assignment\data\CGN1025S.pkl
# After ImportFS: False
# After Timestr: False
# After TimeafterMidnight: False
# After Servicetype: False
# After aircrafttype: False
# After daterange: False
# After all spaces have been removed: False
# After newfs: False
#          13367576 function calls (13366895 primitive calls) in 15.679 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.009    0.009 1240402559.py:1(reduce_numberofcolumns)
#         1    0.001    0.001    0.052    0.052 1351075272.py:1(convert_timestr)
#         1    0.000    0.000   13.285   13.285 2179123048.py:1(import_fs)
#         1    0.000    0.000    0.021    0.021 2845491082.py:1(filter_stype_CJ)
#     23997    0.004    0.000    0.004    0.000 2845491082.py:6(<lambda>)
#         1    0.000    0.000    0.069    0.069 2876237673.py:1(count_operatingweeklytime)
#     43414    0.022    0.000    0.022    0.000 2876237673.py:7(<genexpr>)
#     19427    0.016    0.000    0.052    0.000 2876237673.py:7(<lambda>)
#         1    0.002    0.002   15.678   15.678 2971906180.py:1(import_flightschedule)
#         1    0.003    0.003    1.066    1.066 322773955.py:1(convert_dates)
#     19427    0.116    0.000    0.611    0.000 322773955.py:10(<lambda>)
#         1    0.000    0.000    0.056    0.056 3276586583.py:1(calculate_timeaftermidnight)
#         1    0.001    0.001    0.116    0.116 672318081.py:1(removespaces)
#     97135    0.039    0.000    0.053    0.000 672318081.py:7(<lambda>)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(all)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(append)
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(argsort)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(array_equal)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_1d)
#         7    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_2d)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(bincount)
#        28    0.000    0.000    0.004    0.000 <__array_function__ internals>:177(concatenate)
#        37    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copyto)
#        16    0.000    0.000    0.008    0.001 <__array_function__ internals>:177(delete)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(insert)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(moveaxis)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(ravel)
#         7    0.000    0.000    0.004    0.001 <__array_function__ internals>:177(vstack)
#         3    0.000    0.000    0.000    0.000 <frozen _collections_abc>:280(__iter__)
#         3    0.000    0.000    0.000    0.000 <frozen abc>:105(__new__)
#        33    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#         3    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:100(acquire)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1028(__enter__)
#         6    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1032(__exit__)
#         1    0.000    0.000    0.077    0.077 <frozen importlib._bootstrap>:1056(_find_spec)
#         2    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1103(_sanity_check)
#         1    0.000    0.000    0.078    0.078 <frozen importlib._bootstrap>:1122(_find_and_load_unlocked)
#         2    0.000    0.000    0.078    0.039 <frozen importlib._bootstrap>:1167(_find_and_load)
#         2    0.000    0.000    0.078    0.039 <frozen importlib._bootstrap>:1194(_gcd_import)
#        56    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1209(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:125(release)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:165(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:169(__enter__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:173(__exit__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:179(_get_module_lock)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:198(cb)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:233(_call_with_frames_removed)
#        45    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:244(_verbose_message)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:357(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:71(__init__)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:748(find_spec)
#         1    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:922(find_spec)
#        45    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:119(<listcomp>)
#         9    0.000    0.000    0.076    0.008 <frozen importlib._bootstrap_external>:140(_path_stat)
#        10    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1421(_path_importer_cache)
#         1    0.000    0.000    0.077    0.077 <frozen importlib._bootstrap_external>:1464(_get_spec)
#         1    0.000    0.000    0.077    0.077 <frozen importlib._bootstrap_external>:1496(find_spec)
#         9    0.000    0.000    0.077    0.009 <frozen importlib._bootstrap_external>:1604(find_spec)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:67(_relax_case)
#        45    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:96(_path_join)
#         2    0.000    0.000    0.000    0.000 <frozen ntpath>:107(join)
#         6    0.000    0.000    0.000    0.000 <frozen ntpath>:154(splitdrive)
#         8    0.000    0.000    0.000    0.000 <frozen ntpath>:319(expanduser)
#         4    0.000    0.000    0.000    0.000 <frozen posixpath>:100(split)
#         2    0.000    0.000    0.000    0.000 <frozen posixpath>:150(dirname)
#         6    0.000    0.000    0.000    0.000 <frozen posixpath>:350(normpath)
#        14    0.000    0.000    0.000    0.000 <frozen posixpath>:41(_get_sep)
#         8    0.000    0.000    0.000    0.000 <frozen posixpath>:71(join)
#         4    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         1    0.001    0.001   15.678   15.678 <string>:1(<module>)
#         4    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         3    0.000    0.000    0.000    0.000 ElementTree.py:1222(iterparse)
# 725733/725732    0.236    0.000    8.101    0.000 ElementTree.py:1241(iterator)
#         3    0.000    0.000    0.000    0.000 ElementTree.py:1262(IterParseIterator)
#         3    0.000    0.000    0.000    0.000 ElementTree.py:1274(__init__)
#       816    0.003    0.000    6.877    0.008 ElementTree.py:1286(feed)
#         2    0.000    0.000    0.000    0.000 ElementTree.py:1296(_close_and_return_root)
#    726548    0.690    0.000    0.886    0.000 ElementTree.py:1310(read_events)
#         3    0.000    0.000    0.000    0.000 ElementTree.py:1516(__init__)
#         3    0.000    0.000    0.000    0.000 ElementTree.py:1561(_setevents)
#    726610    0.571    0.000    1.657    0.000 ElementTree.py:1578(handler)
#   2196867    0.733    0.000    0.733    0.000 ElementTree.py:1620(_fixname)
#    726613    1.991    0.000    3.200    0.000 ElementTree.py:1637(_start)
#    726610    0.649    0.000    0.994    0.000 ElementTree.py:1649(_end)
#         6    0.000    0.000    0.000    0.000 ElementTree.py:1652(_default)
#       816    0.003    0.000    6.875    0.008 ElementTree.py:1706(feed)
#         2    0.000    0.000    0.000    0.000 ElementTree.py:1713(close)
#         3    0.000    0.000    0.000    0.000 ElementTree.py:80(__init__)
#         2    0.000    0.000    0.078    0.039 __init__.py:108(import_module)
#         1    0.000    0.000    0.000    0.000 __init__.py:144(__lt__)
#         1    0.000    0.000    0.000    0.000 __init__.py:146(_DType_reduce)
#         6    0.000    0.000    0.000    0.000 __init__.py:152(align_method_SERIES)
#         4    0.000    0.000    0.000    0.000 __init__.py:173(search)
#        19    0.000    0.000    0.000    0.000 __init__.py:225(compile)
#         1    0.000    0.000    0.000    0.000 __init__.py:24(_module_matches_namespace)
#         1    0.000    0.000    0.000    0.000 __init__.py:253(escape)
#        23    0.000    0.000    0.000    0.000 __init__.py:272(_compile)
#         2    0.000    0.000    0.000    0.000 __init__.py:336(__init__)
#         8    0.000    0.000    0.000    0.000 __init__.py:346(<genexpr>)
#         6    0.000    0.000    0.000    0.000 __init__.py:468(_parse_letter_version)
#         2    0.000    0.000    0.000    0.000 __init__.py:507(_parse_local_version)
#         2    0.000    0.000    0.000    0.000 __init__.py:519(_cmpkey)
#         2    0.000    0.000    0.000    0.000 __init__.py:534(<lambda>)
#         1    0.000    0.000    0.000    0.000 __init__.py:57(find_spec)
#         1    0.000    0.000    0.000    0.000 __init__.py:89(find_spec)
#         1    0.000    0.000    0.000    0.000 __init__.py:96(<lambda>)
#         4    0.000    0.000    0.000    0.000 _asarray.py:112(<setcomp>)
#         4    0.000    0.000    0.000    0.000 _asarray.py:31(require)
#         1    0.000    0.000    0.027    0.027 _base.py:1494(inspect_excel_format)
#         5    0.000    0.000    0.000    0.000 _base.py:1538(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _base.py:1546(<listcomp>)
#         1    0.000    0.000    0.349    0.349 _base.py:1620(__init__)
#         1    0.000    0.000   12.936   12.936 _base.py:1700(parse)
#         2    0.000    0.000    0.000    0.000 _base.py:1765(close)
#         1    0.000    0.000    0.000    0.000 _base.py:1775(__del__)
#         1    0.000    0.000   13.285   13.285 _base.py:440(read_excel)
#         1    0.000    0.000    0.244    0.244 _base.py:524(__init__)
#         2    0.000    0.000    0.000    0.000 _base.py:563(close)
#         1    0.000    0.000    0.000    0.000 _base.py:593(raise_if_bad_sheet_by_index)
#         1    0.000    0.000    0.000    0.000 _base.py:633(_calc_rows)
#         1    0.002    0.002   12.936   12.936 _base.py:697(parse)
#         1    0.000    0.000   13.285   13.285 _decorators.py:170(wrapper)
#       2/1    0.000    0.000   13.285   13.285 _decorators.py:323(wrapper)
#         5    0.000    0.000    0.000    0.000 _dtype.py:178(_datetime_metadata_str)
#        33    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#        33    0.000    0.000    0.000    0.000 _dtype.py:330(_name_includes_bit_suffix)
#        33    0.000    0.000    0.000    0.000 _dtype.py:344(_name_get)
#         7    0.000    0.000    0.000    0.000 _methods.py:39(_amax)
#         4    0.000    0.000    0.000    0.000 _methods.py:43(_amin)
#         4    0.000    0.000    0.000    0.000 _methods.py:47(_sum)
#         9    0.000    0.000    0.000    0.000 _methods.py:55(_any)
#         7    0.000    0.000    0.000    0.000 _methods.py:61(_all)
#         5    0.000    0.000    0.001    0.000 _mixins.py:154(take)
#         6    0.000    0.000    0.000    0.000 _mixins.py:283(__getitem__)
#         1    0.000    0.000    0.244    0.244 _openpyxl.py:541(__init__)
#         2    0.000    0.000    0.000    0.000 _openpyxl.py:559(_workbook_class)
#         1    0.000    0.000    0.229    0.229 _openpyxl.py:565(load_workbook)
#         1    0.000    0.000    0.000    0.000 _openpyxl.py:572(sheet_names)
#         1    0.000    0.000    0.000    0.000 _openpyxl.py:574(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _openpyxl.py:580(get_sheet_by_index)
#    335972    1.282    0.000    1.438    0.000 _openpyxl.py:584(_convert_cell)
#         1    0.107    0.107   12.854   12.854 _openpyxl.py:606(get_sheet_data)
#     23998    0.189    0.000    1.627    0.000 _openpyxl.py:616(<listcomp>)
#     23999    0.010    0.000    0.013    0.000 _openpyxl.py:631(<genexpr>)
#     23999    0.010    0.000    0.012    0.000 _openpyxl.py:632(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _optional.py:69(get_version)
#         2    0.000    0.000    0.078    0.039 _optional.py:90(import_optional_dependency)
#       288    0.001    0.000    0.001    0.000 _parser.py:1006(_find_hms_idx)
#       288    0.000    0.000    0.000    0.000 _parser.py:1099(_parse_min_sec)
#       288    0.000    0.000    0.000    0.000 _parser.py:1133(_parsems)
#       576    0.001    0.000    0.001    0.000 _parser.py:1141(_to_decimal)
#       288    0.000    0.000    0.000    0.000 _parser.py:1177(_build_tzaware)
#       288    0.002    0.000    0.004    0.000 _parser.py:1217(_build_naive)
#       288    0.001    0.000    0.040    0.000 _parser.py:1270(parse)
#       288    0.000    0.000    0.000    0.000 _parser.py:186(__iter__)
#      1728    0.001    0.000    0.013    0.000 _parser.py:189(__next__)
#       288    0.002    0.000    0.016    0.000 _parser.py:199(split)
#      1440    0.001    0.000    0.001    0.000 _parser.py:203(isword)
#      2880    0.001    0.000    0.002    0.000 _parser.py:208(isnum)
#       576    0.000    0.000    0.000    0.000 _parser.py:213(isspace)
#       288    0.001    0.000    0.002    0.000 _parser.py:221(__init__)
#       288    0.001    0.000    0.003    0.000 _parser.py:233(__len__)
#      3744    0.002    0.000    0.002    0.000 _parser.py:234(<genexpr>)
#       288    0.001    0.000    0.001    0.000 _parser.py:336(hms)
#       288    0.000    0.000    0.000    0.000 _parser.py:380(validate)
#       288    0.001    0.000    0.001    0.000 _parser.py:395(__init__)
#       288    0.001    0.000    0.002    0.000 _parser.py:474(resolve_ymd)
#       288    0.000    0.000    0.000    0.000 _parser.py:482(<dictcomp>)
#       288    0.002    0.000    0.040    0.000 _parser.py:572(parse)
#       288    0.001    0.000    0.001    0.000 _parser.py:62(__init__)
#       288    0.003    0.000    0.028    0.000 _parser.py:666(_parse)
#      1728    0.008    0.000    0.011    0.000 _parser.py:77(get_token)
#       288    0.002    0.000    0.006    0.000 _parser.py:875(_parse_numeric_token)
#     23998    0.673    0.000    1.178    0.000 _read_only.py:101(_get_row)
#         1    0.000    0.000    0.000    0.000 _read_only.py:160(reset_dimensions)
#         2    0.000    0.000    0.000    0.000 _read_only.py:174(max_row)
#         2    0.000    0.000    0.000    0.000 _read_only.py:184(max_column)
#         1    0.000    0.000    0.008    0.008 _read_only.py:34(__init__)
#         1    0.000    0.000    0.008    0.008 _read_only.py:44(_get_size)
#         2    0.000    0.000    0.000    0.000 _read_only.py:53(_get_source)
#     23999    1.869    0.000   11.080    0.000 _read_only.py:58(_cells_by_row)
#        28    0.000    0.000    0.000    0.000 _ufunc_config.py:132(geterr)
#        28    0.000    0.000    0.000    0.000 _ufunc_config.py:33(seterr)
#        14    0.000    0.000    0.000    0.000 _ufunc_config.py:426(__init__)
#        14    0.000    0.000    0.000    0.000 _ufunc_config.py:430(__enter__)
#        14    0.000    0.000    0.000    0.000 _ufunc_config.py:435(__exit__)
#         1    0.000    0.000    0.000    0.000 _util.py:182(maybe_convert_usecols)
#         1    0.000    0.000    0.000    0.000 _util.py:48(get_default_engine)
#         1    0.000    0.000    0.000    0.000 _validators.py:226(validate_bool_kwarg)
#         3    0.000    0.000    0.001    0.000 accessor.py:178(__get__)
#         1    0.000    0.000    0.001    0.001 accessor.py:178(__init__)
#         1    0.000    0.000    0.001    0.001 accessor.py:197(_validate)
#         2    0.000    0.000    0.040    0.020 accessor.py:238(__getitem__)
#         2    0.000    0.000    0.001    0.000 accessor.py:255(_wrap_result)
#         3    0.000    0.000    0.005    0.002 accessor.py:79(_getter)
#         2    0.000    0.000    0.000    0.000 accessors.py:482(__new__)
#         2    0.000    0.000    0.000    0.000 accessors.py:53(__init__)
#         3    0.000    0.000    0.001    0.000 accessors.py:64(_get_values)
#         3    0.000    0.000    0.005    0.002 accessors.py:82(_delegate_property_get)
#         3    0.000    0.000    0.000    0.000 algorithms.py:117(_ensure_data)
#         8    0.000    0.000    0.001    0.000 algorithms.py:1484(take)
#         3    0.000    0.000    0.000    0.000 algorithms.py:197(_reconstruct_data)
#         3    0.000    0.000    0.000    0.000 algorithms.py:235(_ensure_arraylike)
#         3    0.000    0.000    0.001    0.000 algorithms.py:269(_get_hashtable_algo)
#         3    0.000    0.000    0.000    0.000 algorithms.py:287(_check_object_for_strings)
#         3    0.000    0.000    0.003    0.001 algorithms.py:315(unique)
#         3    0.000    0.000    0.003    0.001 algorithms.py:412(unique_with_mask)
#         4    0.000    0.000    0.000    0.000 alignment.py:45(__init__)
#        16    0.000    0.000    0.000    0.000 alignment.py:68(__iter__)
#     19428    0.060    0.000    0.200    0.000 apply.py:1016(series_generator)
#         1    0.000    0.000    0.000    0.000 apply.py:1042(result_index)
#         7    0.000    0.000    0.000    0.000 apply.py:1089(__init__)
#         7    0.000    0.000    0.186    0.027 apply.py:1108(apply)
#         8    0.000    0.000    0.000    0.000 apply.py:112(__init__)
#         7    0.000    0.000    0.186    0.027 apply.py:1159(apply_standard)
#         2    0.000    0.000    0.000    0.000 apply.py:673(index)
#         1    0.000    0.000    0.000    0.000 apply.py:719(columns)
#         1    0.000    0.000    0.070    0.070 apply.py:723(values)
#         1    0.001    0.001    1.051    1.051 apply.py:731(apply)
#         1    0.000    0.000    0.000    0.000 apply.py:82(frame_apply)
#         1    0.000    0.000    1.050    1.050 apply.py:890(apply_standard)
#         1    0.039    0.039    0.894    0.894 apply.py:896(apply_series_generator)
#         1    0.000    0.000    0.156    0.156 apply.py:915(wrap_results)
#         6    0.000    0.000    0.006    0.001 array_ops.py:136(_na_arithmetic_op)
#         6    0.000    0.000    0.006    0.001 array_ops.py:185(arithmetic_op)
#         6    0.000    0.000    0.000    0.000 array_ops.py:445(maybe_prepare_scalar_for_op)
#         6    0.000    0.000    0.000    0.000 array_ops.py:514(_bool_arith_check)
#         5    0.000    0.000    0.008    0.002 arraylike.py:100(__add__)
#         1    0.000    0.000    0.000    0.000 arraylike.py:116(__mul__)
#         7    0.000    0.000    0.001    0.000 astype.py:192(astype_array)
#         7    0.000    0.000    0.001    0.000 astype.py:239(astype_array_safe)
#         3    0.000    0.000    0.008    0.003 astype.py:68(astype_nansafe)
#        16    0.000    0.000    0.000    0.000 base.py:102(__set__)
#         3    0.000    0.000    0.000    0.000 base.py:1168(take)
#         3    0.000    0.000    0.000    0.000 base.py:1194(_maybe_disallow_fill)
#        52    0.000    0.000    0.000    0.000 base.py:126(__set__)
#         6    0.000    0.000    0.008    0.001 base.py:1316(_arith_method)
#        52    0.000    0.000    0.000    0.000 base.py:140(__set__)
#         1    0.000    0.000    0.000    0.000 base.py:148(is_consolidated)
#       191    0.000    0.000    0.001    0.000 base.py:160(__set__)
#         3    0.000    0.000    0.000    0.000 base.py:161(_freeze)
#         2    0.000    0.000    0.000    0.000 base.py:163(array)
#        16    0.000    0.000    0.000    0.000 base.py:168(__setattr__)
#        18    0.000    0.000    0.000    0.000 base.py:1734(name)
#         1    0.000    0.000    0.000    0.000 base.py:2017(nlevels)
#         2    0.000    0.000    0.000    0.000 base.py:210(interleaved_dtype)
#         7    0.000    0.000    0.000    0.000 base.py:226(__set__)
#      8660    0.005    0.000    0.006    0.000 base.py:229(__get__)
#     12264    0.006    0.000    0.006    0.000 base.py:23(__set__)
#         7    0.000    0.000    0.000    0.000 base.py:2381(is_unique)
#        21    0.000    0.000    0.000    0.000 base.py:241(disallow_kwargs)
#        10    0.000    0.000    0.000    0.000 base.py:2421(is_boolean)
#        30    0.000    0.000    0.000    0.000 base.py:245(__set__)
#         6    0.000    0.000    0.000    0.000 base.py:262(__set__)
#         5    0.000    0.000    0.000    0.000 base.py:2745(inferred_type)
#        10    0.000    0.000    0.000    0.000 base.py:2752(_is_all_dates)
#        17    0.000    0.000    0.000    0.000 base.py:2783(_is_multi)
#         2    0.000    0.000    0.000    0.000 base.py:2794(__reduce__)
#         2    0.000    0.000    0.000    0.000 base.py:2801(_na_value)
#        67    0.000    0.000    0.001    0.000 base.py:286(is_dtype)
#         2    0.000    0.000    0.039    0.019 base.py:32(_str_getitem)
#        88    0.000    0.000    0.000    0.000 base.py:324(ndim)
#         3    0.000    0.000    0.000    0.000 base.py:356(size)
#     38878    0.048    0.000    0.092    0.000 base.py:3754(get_loc)
#      6373    0.010    0.000    0.016    0.000 base.py:38(__set__)
#         5    0.000    0.000    0.004    0.001 base.py:3888(get_indexer)
#         5    0.000    0.000    0.002    0.000 base.py:3975(_get_indexer)
#         5    0.000    0.000    0.000    0.000 base.py:4020(_check_indexing_method)
#         5    0.000    0.000    0.000    0.000 base.py:413(_engine_type)
#     28/21    0.001    0.000    0.014    0.001 base.py:430(__new__)
#         1    0.000    0.000    0.000    0.000 base.py:4318(reindex)
#         1    0.000    0.000    0.000    0.000 base.py:4437(_wrap_reindex_result)
#         1    0.000    0.000    0.000    0.000 base.py:4441(_maybe_preserve_names)
#        19    0.000    0.000    0.000    0.000 base.py:46(__len__)
#      3087    0.002    0.000    0.002    0.000 base.py:49(_convert)
#        36    0.000    0.000    0.000    0.000 base.py:494(find)
#        82    0.000    0.000    0.000    0.000 base.py:5090(_values)
#        12    0.000    0.000    0.000    0.000 base.py:5116(_get_engine_target)
#         3    0.000    0.000    0.000    0.000 base.py:5204(_validate_fill_value)
#        38    0.000    0.000    0.000    0.000 base.py:5254(__contains__)
#        25    0.000    0.000    0.000    0.000 base.py:5304(__getitem__)
#        18    0.000    0.000    0.000    0.000 base.py:54(shape)
#         3    0.000    0.000    0.000    0.000 base.py:543(empty)
#        18    0.000    0.000    0.000    0.000 base.py:5464(equals)
#         4    0.000    0.000    0.000    0.000 base.py:555(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base.py:5551(identical)
#         2    0.000    0.000    0.000    0.000 base.py:5564(<genexpr>)
#        54    0.000    0.000    0.000    0.000 base.py:56(<genexpr>)
#        13    0.000    0.000    0.000    0.000 base.py:574(_ensure_array)
#        51    0.000    0.000    0.000    0.000 base.py:58(_validate_set_axis)
#        21    0.000    0.000    0.000    0.000 base.py:588(_dtype_to_subclass)
#     38854    0.045    0.000    0.092    0.000 base.py:5934(_get_values_for_loc)
#         1    0.000    0.000    0.001    0.001 base.py:6032(get_indexer_for)
#         1    0.000    0.000    0.001    0.001 base.py:6056(_get_indexer_strict)
#         1    0.000    0.000    0.000    0.000 base.py:6087(_raise_if_missing)
#         8    0.000    0.000    0.000    0.000 base.py:6193(_index_as_unique)
#         5    0.000    0.000    0.000    0.000 base.py:6205(_maybe_promote)
#         5    0.000    0.000    0.000    0.000 base.py:6285(_should_compare)
#         5    0.000    0.000    0.000    0.000 base.py:6303(_is_comparable_dtype)
#      3259    0.007    0.000    0.016    0.000 base.py:64(__set__)
#     38878    0.006    0.000    0.006    0.000 base.py:6569(_maybe_cast_indexer)
#         5    0.000    0.000    0.001    0.000 base.py:6576(_maybe_cast_listlike_indexer)
#         3    0.000    0.000    0.002    0.001 base.py:6844(insert)
#        30    0.000    0.000    0.000    0.000 base.py:690(_simple_new)
#        18    0.000    0.000    0.014    0.001 base.py:708(_with_infer)
#        92    0.000    0.000    0.013    0.000 base.py:7277(ensure_index)
#         1    0.000    0.000    0.000    0.000 base.py:728(_constructor)
#         1    0.000    0.000    0.000    0.000 base.py:7336(ensure_has_len)
#        85    0.000    0.000    0.001    0.000 base.py:7372(maybe_extract_name)
#        14    0.000    0.000    0.009    0.001 base.py:7396(_maybe_cast_data_without_dtype)
#         5    0.000    0.000    0.000    0.000 base.py:742(__iter__)
#         5    0.000    0.000    0.000    0.000 base.py:7456(unpack_nested_dtype)
#         3    0.000    0.000    0.004    0.001 base.py:796(_map_values)
#        12    0.000    0.000    0.000    0.000 base.py:82(__set__)
#        18    0.000    0.000    0.000    0.000 base.py:839(is_)
#        31    0.000    0.000    0.000    0.000 base.py:870(_reset_identity)
#         7    0.000    0.000    0.000    0.000 base.py:881(_engine)
#       184    0.000    0.000    0.000    0.000 base.py:925(__len__)
#         3    0.000    0.000    0.000    0.000 base.py:931(__array__)
#        21    0.000    0.000    0.000    0.000 base.py:986(dtype)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1056(_make_date_converter)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1148(_process_date_conversion)
#        14    0.000    0.000    0.000    0.000 base_parser.py:1248(_get_na_values)
#         2    0.000    0.000    0.000    0.000 base_parser.py:1283(_is_potential_multi_index)
#         4    0.000    0.000    0.000    0.000 base_parser.py:1308(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1312(_validate_parse_dates_arg)
#         3    0.000    0.000    0.000    0.000 base_parser.py:1334(is_index_col)
#         1    0.000    0.000    0.000    0.000 base_parser.py:165(_validate_parse_dates_presence)
#         1    0.000    0.000    0.000    0.000 base_parser.py:209(<setcomp>)
#         1    0.000    0.000    0.000    0.000 base_parser.py:221(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base_parser.py:229(_has_complex_date_col)
#         1    0.000    0.000    0.000    0.000 base_parser.py:258(_extract_multi_indexer_columns)
#         1    0.000    0.000    0.000    0.000 base_parser.py:327(_maybe_dedup_names)
#         1    0.000    0.000    0.000    0.000 base_parser.py:358(_maybe_make_multi_index_columns)
#         1    0.000    0.000    0.000    0.000 base_parser.py:370(_make_index)
#         2    0.000    0.000    0.000    0.000 base_parser.py:452(_clean_mapping)
#         1    0.000    0.000    0.038    0.038 base_parser.py:519(_convert_to_ndarrays)
#        14    0.000    0.000    0.029    0.002 base_parser.py:681(_infer_types)
#         3    0.000    0.000    0.008    0.003 base_parser.py:734(_cast_types)
#         1    0.000    0.000    0.000    0.000 base_parser.py:814(_do_date_conversions)
#         1    0.000    0.000    0.000    0.000 base_parser.py:834(_check_data_length)
#         1    0.000    0.000    0.000    0.000 base_parser.py:88(__init__)
#         1    0.000    0.000    0.000    0.000 base_parser.py:924(_validate_usecols_arg)
#         1    0.000    0.000    0.000    0.000 base_parser.py:973(_clean_index_names)
#         1    0.000    0.000    0.063    0.063 blocks.py:1598(get_values)
#        23    0.000    0.000    0.000    0.000 blocks.py:160(_consolidate_key)
#         2    0.000    0.000    0.000    0.000 blocks.py:1908(array_values)
#         2    0.000    0.000    0.002    0.001 blocks.py:1912(get_values)
#         8    0.000    0.000    0.008    0.001 blocks.py:1920(delete)
#         3    0.000    0.000    0.000    0.000 blocks.py:1939(is_extension)
#         6    0.000    0.000    0.000    0.000 blocks.py:200(fill_value)
#        64    0.000    0.000    0.001    0.000 blocks.py:2091(maybe_coerce_values)
#        61    0.000    0.000    0.000    0.000 blocks.py:2120(get_block_type)
#        52    0.000    0.000    0.000    0.000 blocks.py:213(mgr_locs)
#        19    0.000    0.000    0.001    0.000 blocks.py:2161(new_block_2d)
#        38    0.000    0.000    0.001    0.000 blocks.py:2172(new_block)
#        38    0.000    0.000    0.000    0.000 blocks.py:2186(check_ndim)
#         7    0.000    0.000    0.000    0.000 blocks.py:221(make_block)
#        19    0.000    0.000    0.000    0.000 blocks.py:2250(extend_blocks)
#        12    0.000    0.000    0.000    0.000 blocks.py:2266(ensure_block_shape)
#         6    0.000    0.000    0.000    0.000 blocks.py:236(make_block_same_class)
#         8    0.000    0.000    0.000    0.000 blocks.py:275(__len__)
#        56    0.000    0.000    0.000    0.000 blocks.py:500(dtype)
#         7    0.000    0.000    0.002    0.000 blocks.py:504(astype)
#         1    0.000    0.000    0.000    0.000 blocks.py:544(copy)
#        15    0.000    0.000    0.000    0.000 blocks.py:823(shape)
#        28    0.000    0.000    0.000    0.000 blocks.py:827(iget)
#         6    0.000    0.000    0.005    0.001 blocks.py:861(take_nd)
#         5    0.000    0.000    0.000    0.000 borders.py:105(__iter__)
#        10    0.000    0.000    0.000    0.000 borders.py:49(__init__)
#         2    0.000    0.000    0.000    0.000 borders.py:87(__init__)
#         2    0.000    0.000    0.000    0.000 bound_dictionary.py:17(__init__)
#       288    0.001    0.000    0.001    0.000 calendar.py:115(weekday)
#       288    0.000    0.000    0.001    0.000 calendar.py:122(monthrange)
#        21    0.000    0.000    0.068    0.003 cast.py:1178(maybe_infer_to_datetimelike)
#         1    0.000    0.000    0.076    0.076 cast.py:120(maybe_convert_platform)
#         1    0.000    0.000    0.066    0.066 cast.py:1229(try_timedelta)
#        11    0.000    0.000    0.000    0.000 cast.py:1422(sanitize_to_nanoseconds)
#         2    0.000    0.000    0.000    0.000 cast.py:1589(find_common_type)
#         8    0.000    0.000    0.000    0.000 cast.py:1619(<genexpr>)
#         6    0.000    0.000    0.000    0.000 cast.py:1628(<genexpr>)
#         4    0.000    0.000    0.000    0.000 cast.py:1630(<genexpr>)
#         8    0.000    0.000    0.000    0.000 cast.py:1635(<genexpr>)
#         7    0.076    0.011    0.076    0.011 cast.py:1763(construct_1d_object_array_from_listlike)
#         1    0.000    0.000    0.000    0.000 cast.py:1788(maybe_cast_to_integer_array)
#         3    0.000    0.000    0.000    0.000 cast.py:1931(np_can_hold_element)
#        10    0.000    0.000    0.000    0.000 cast.py:508(ensure_dtype_can_hold_na)
#        14    0.000    0.000    0.000    0.000 cast.py:527(maybe_promote)
#        10    0.000    0.000    0.000    0.000 cast.py:574(_maybe_promote)
#         1    0.000    0.000    0.000    0.000 cell_range.py:426(__init__)
#         4    0.000    0.000    0.000    0.000 cell_style.py:126(to_array)
#         2    0.000    0.000    0.000    0.000 cell_style.py:172(__init__)
#         1    0.000    0.000    0.000    0.000 cell_style.py:184(__getitem__)
#         1    0.000    0.000    0.000    0.000 cell_style.py:188(_to_array)
#         9    0.000    0.000    0.000    0.000 cell_style.py:26(__get__)
#        38    0.000    0.000    0.000    0.000 cell_style.py:29(__set__)
#         7    0.000    0.000    0.000    0.000 cell_style.py:52(__new__)
#         5    0.000    0.000    0.000    0.000 cell_style.py:56(__hash__)
#         5    0.000    0.000    0.000    0.000 cell_style.py:93(__init__)
#         1    0.000    0.000    0.000    0.000 child.py:15(avoid_duplicate_name)
#         1    0.000    0.000    0.000    0.000 child.py:22(<listcomp>)
#         1    0.000    0.000    0.000    0.000 child.py:45(__init__)
#         1    0.000    0.000    0.000    0.000 child.py:55(parent)
#         2    0.000    0.000    0.000    0.000 child.py:65(title)
#         1    0.000    0.000    0.000    0.000 child.py:70(title)
#        26    0.000    0.000    0.000    0.000 colors.py:105(__iter__)
#        17    0.000    0.000    0.000    0.000 colors.py:131(__set__)
#         2    0.000    0.000    0.000    0.000 colors.py:80(__init__)
#        13    0.000    0.000    0.000    0.000 colors.py:97(value)
#         3    0.000    0.000    0.000    0.000 common.py:102(iterparse)
#         3    0.000    0.000    0.000    0.000 common.py:1102(_maybe_memory_map)
#         4    0.000    0.000    0.039    0.010 common.py:112(close)
#         3    0.000    0.000    0.000    0.000 common.py:1147(_is_binary_mode)
#        34    0.000    0.000    0.000    0.000 common.py:1154(needs_i8_conversion)
#         2    0.000    0.000    0.000    0.000 common.py:116(ensure_python_int)
#         7    0.000    0.000    0.000    0.000 common.py:1204(is_numeric_dtype)
#        45    0.000    0.000    0.000    0.000 common.py:1246(is_float_dtype)
#        23    0.000    0.000    0.000    0.000 common.py:1278(is_bool_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:129(__enter__)
#         2    0.000    0.000    0.038    0.019 common.py:132(__exit__)
#         3    0.000    0.000    0.000    0.000 common.py:136(is_url)
#         5    0.000    0.000    0.000    0.000 common.py:1403(is_1d_only_ea_obj)
#        73    0.000    0.000    0.000    0.000 common.py:1420(is_1d_only_ea_dtype)
#        63    0.000    0.000    0.000    0.000 common.py:1433(is_extension_array_dtype)
#       113    0.000    0.000    0.000    0.000 common.py:146(classes)
#       113    0.000    0.000    0.000    0.000 common.py:148(<lambda>)
#        56    0.000    0.000    0.000    0.000 common.py:1487(is_ea_or_datetimelike_dtype)
#        25    0.000    0.000    0.000    0.000 common.py:151(cast_scalar_indexer)
#        67    0.000    0.000    0.000    0.000 common.py:151(classes_and_not_datetimelike)
#        22    0.000    0.000    0.000    0.000 common.py:1532(_is_dtype)
#       118    0.000    0.000    0.000    0.000 common.py:1556(get_dtype)
#        67    0.000    0.000    0.000    0.000 common.py:156(<lambda>)
#       180    0.000    0.000    0.001    0.000 common.py:1591(_is_dtype_type)
#        64    0.000    0.000    0.000    0.000 common.py:162(is_object_dtype)
#         8    0.000    0.000    0.000    0.000 common.py:164(_expand_user)
#        97    0.000    0.000    0.000    0.000 common.py:1725(validate_all_hashable)
#       194    0.000    0.000    0.000    0.000 common.py:1744(<genexpr>)
#        41    0.000    0.000    0.000    0.000 common.py:1751(pandas_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:183(validate_header_arg)
#         2    0.000    0.000    0.000    0.000 common.py:192(all_none)
#         6    0.000    0.000    0.000    0.000 common.py:192(is_sparse)
#         6    0.000    0.000    0.000    0.000 common.py:196(<genexpr>)
#         5    0.000    0.000    0.000    0.000 common.py:224(stringify_path)
#        21    0.000    0.000    0.001    0.000 common.py:235(asarray_tuplesafe)
#         3    0.000    0.000    0.000    0.000 common.py:268(is_fsspec_url)
#         3    0.000    0.000    0.000    0.000 common.py:280(_get_filepath_or_buffer)
#         5    0.000    0.000    0.000    0.000 common.py:303(maybe_iterable_to_list)
#        31    0.000    0.000    0.000    0.000 common.py:319(is_datetime64_dtype)
#        18    0.000    0.000    0.000    0.000 common.py:352(is_datetime64tz_dtype)
#     38882    0.016    0.000    0.022    0.000 common.py:362(apply_if_callable)
#        18    0.000    0.000    0.000    0.000 common.py:393(is_timedelta64_dtype)
#        13    0.000    0.000    0.000    0.000 common.py:427(is_period_dtype)
#         5    0.000    0.000    0.000    0.000 common.py:463(is_interval_dtype)
#         3    0.000    0.000    0.000    0.000 common.py:494(get_compression_method)
#        31    0.000    0.000    0.000    0.000 common.py:501(is_categorical_dtype)
#         3    0.000    0.000    0.000    0.000 common.py:529(infer_compression)
#         6    0.000    0.000    0.000    0.000 common.py:537(is_string_or_object_np_dtype)
#        22    0.000    0.000    0.000    0.000 common.py:544(is_string_dtype)
#        44    0.000    0.000    0.000    0.000 common.py:566(require_length_match)
#         6    0.000    0.000    0.008    0.001 common.py:57(new_method)
#        11    0.000    0.000    0.000    0.000 common.py:573(condition)
#         3    0.000    0.000    0.000    0.000 common.py:576(is_excluded_dtype)
#        40    0.000    0.000    0.000    0.000 common.py:585(is_dtype_equal)
#         1    0.000    0.000    0.001    0.001 common.py:586(check_parent_directory)
#         3    0.000    0.000    0.074    0.025 common.py:645(get_handle)
#        14    0.000    0.000    0.000    0.000 common.py:684(is_integer_dtype)
#        25    0.000    0.000    0.000    0.000 common.py:736(is_signed_integer_dtype)
#         6    0.000    0.000    0.000    0.000 common.py:77(get_op_result_name)
#        21    0.000    0.000    0.000    0.000 common.py:790(is_unsigned_integer_dtype)
#         4    0.000    0.000    0.000    0.000 common.py:929(is_datetime64_ns_dtype)
#         2    0.000    0.000    0.000    0.000 common.py:96(is_bool_indexer)
#         2    0.000    0.000    0.000    0.000 common.py:99(_maybe_match_name)
#        48    0.000    0.000    0.001    0.000 config.py:116(_get_single_key)
#        46    0.000    0.000    0.001    0.000 config.py:134(_get_option)
#         2    0.000    0.000    0.000    0.000 config.py:142(_set_option)
#        45    0.000    0.000    0.001    0.000 config.py:262(__call__)
#         1    0.000    0.000    0.000    0.000 config.py:433(__init__)
#         1    0.000    0.000    0.000    0.000 config.py:441(__enter__)
#         1    0.000    0.000    0.000    0.000 config.py:442(<listcomp>)
#         1    0.000    0.000    0.000    0.000 config.py:447(__exit__)
#        48    0.000    0.000    0.000    0.000 config.py:579(_select_options)
#        48    0.000    0.000    0.000    0.000 config.py:597(_get_root)
#        92    0.000    0.000    0.000    0.000 config.py:611(_get_deprecated_option)
#         2    0.000    0.000    0.000    0.000 config.py:627(_get_registered_option)
#        48    0.000    0.000    0.000    0.000 config.py:638(_translate_key)
#        44    0.000    0.000    0.000    0.000 config.py:650(_warn_if_deprecated)
#         2    0.000    0.000    0.000    0.000 config.py:849(inner)
#         1    0.001    0.001    0.011    0.011 construction.py:100(arrays_to_mgr)
#         1    0.000    0.000    0.000    0.000 construction.py:231(mgr_to_mgr)
#        75    0.000    0.000    0.001    0.000 construction.py:399(extract_array)
#         1    0.000    0.000    0.013    0.013 construction.py:423(dict_to_mgr)
#        86    0.000    0.000    0.001    0.000 construction.py:461(ensure_wrapped_if_datetimelike)
#         1    0.000    0.000    0.000    0.000 construction.py:488(<listcomp>)
#        51    0.001    0.000    0.147    0.003 construction.py:493(sanitize_array)
#         1    0.000    0.000    0.001    0.001 construction.py:588(_homogenize)
#        51    0.000    0.000    0.000    0.000 construction.py:676(_sanitize_ndim)
#        45    0.000    0.000    0.000    0.000 construction.py:713(_sanitize_str_dtypes)
#        51    0.000    0.000    0.000    0.000 construction.py:733(_maybe_repeat)
#        44    0.000    0.000    0.001    0.000 construction.py:744(_try_cast)
#        59    0.000    0.000    0.000    0.000 construction.py:861(is_empty_data)
#       9/8    0.000    0.000    0.159    0.020 construction.py:881(create_series_with_explicit_dtype)
#         1    0.000    0.000    0.000    0.000 copy.py:107(_copy_immutable)
#       4/3    0.000    0.000    0.001    0.000 copy.py:66(copy)
#         2    0.000    0.000    0.000    0.000 core.py:81(__init__)
#        36    0.000    0.000    0.000    0.000 cp437.py:14(decode)
#         1    0.000    0.000    0.000    0.000 datavalidation.py:169(__init__)
#         2    0.000    0.000    0.000    0.000 datetime.py:35(from_ISO8601)
#         4    0.000    0.000    0.000    0.000 datetimelike.py:2012(_reso)
#         8    0.000    0.000    0.000    0.000 datetimelike.py:2138(ensure_arraylike_for_datetimelike)
#         8    0.000    0.000    0.000    0.000 datetimelike.py:2206(validate_inferred_freq)
#         7    0.000    0.000    0.000    0.000 datetimelike.py:2243(maybe_infer_freq)
#         7    0.000    0.000    0.000    0.000 datetimelike.py:295(asi8)
#         4    0.000    0.000    0.000    0.000 datetimelike.py:330(__array__)
#         6    0.000    0.000    0.000    0.000 datetimelike.py:347(__getitem__)
#         3    0.000    0.000    0.000    0.000 datetimelike.py:368(_get_getitem_freq)
#         1    0.000    0.000    0.063    0.063 datetimelike.py:425(astype)
#         6    0.000    0.000    0.000    0.000 datetimelike.py:560(copy)
#         4    0.000    0.000    0.000    0.000 datetimelike.py:637(_validate_scalar)
#         3    0.000    0.000    0.000    0.000 datetimelike.py:882(_isnan)
#         3    0.000    0.000    0.000    0.000 datetimelike.py:889(_hasna)
#         2    0.000    0.000    0.000    0.000 datetimelike.py:896(_maybe_mask_results)
#        24    0.000    0.000    0.000    0.000 datetimelike.py:926(freq)
#         2    0.000    0.000    0.002    0.001 datetimes.py:114(f)
#         2    0.000    0.000    0.001    0.000 datetimes.py:1231(_attempt_YYYYMMDD)
#         2    0.000    0.000    0.000    0.000 datetimes.py:1243(calc)
#         3    0.000    0.000    0.000    0.000 datetimes.py:134(should_cache)
#         3    0.000    0.000    0.052    0.017 datetimes.py:194(_maybe_cache)
#         8    0.000    0.000    0.000    0.000 datetimes.py:194(_scalar_type)
#         6    0.000    0.000    0.001    0.000 datetimes.py:1980(_sequence_to_dt64ns)
#         1    0.000    0.000    0.042    0.042 datetimes.py:2129(objects_to_datetime64ns)
#         9    0.000    0.000    0.000    0.000 datetimes.py:2215(maybe_convert_dtype)
#         6    0.000    0.000    0.000    0.000 datetimes.py:2314(_validate_dt64_dtype)
#        12    0.000    0.000    0.000    0.000 datetimes.py:2366(validate_tz_from_dtype)
#         3    0.000    0.000    0.001    0.000 datetimes.py:241(_box_as_indexlike)
#         6    0.000    0.000    0.000    0.000 datetimes.py:265(_simple_new)
#         1    0.000    0.000    0.000    0.000 datetimes.py:286(_from_sequence)
#         6    0.000    0.000    0.001    0.000 datetimes.py:290(_from_sequence_not_strict)
#         5    0.000    0.000    0.001    0.000 datetimes.py:313(__new__)
#         3    0.000    0.000    0.044    0.015 datetimes.py:325(_convert_listlike_datetimes)
#         4    0.000    0.000    0.000    0.000 datetimes.py:449(_unbox_scalar)
#         4    0.000    0.000    0.000    0.000 datetimes.py:458(_check_compatible_with)
#         3    0.000    0.000    0.000    0.000 datetimes.py:483(_box_func)
#        93    0.000    0.000    0.000    0.000 datetimes.py:495(dtype)
#         2    0.000    0.000    0.001    0.000 datetimes.py:506(_to_datetime_with_format)
#        12    0.000    0.000    0.000    0.000 datetimes.py:520(tz)
#         3    0.000    0.000    0.000    0.000 datetimes.py:562(__array__)
#         1    0.000    0.000    0.063    0.063 datetimes.py:599(astype)
#         3    0.000    0.000    0.057    0.019 datetimes.py:705(to_datetime)
#         2    0.000    0.000    0.000    0.000 datetimes.py:739(_local_timestamps)
#         6    0.000    0.000    0.000    0.000 datetimes.py:94(tz_to_dtype)
#         1    0.000    0.000    0.000    0.000 defined_name.py:174(__init__)
#         1    0.000    0.000    0.000    0.000 differential.py:62(__init__)
#         2    0.000    0.000    0.000    0.000 dimensions.py:190(__init__)
#         2    0.000    0.000    0.000    0.000 dimensions.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 dimensions.py:288(__init__)
#         1    0.000    0.000    0.000    0.000 dimensions.py:294(boundaries)
#         6    0.000    0.000    0.000    0.000 dispatch.py:13(should_extension_dispatch)
#         5    0.000    0.000    0.000    0.000 dtypes.py:1247(is_dtype)
#         2    0.000    0.000    0.000    0.000 dtypes.py:1333(__init__)
#        13    0.000    0.000    0.000    0.000 dtypes.py:977(is_dtype)
#        18    0.000    0.000    0.000    0.000 enum.py:1245(value)
#        18    0.000    0.000    0.000    0.000 enum.py:192(__get__)
#         1    0.000    0.000    0.000    0.000 excel.py:100(_find_workbook_part)
#         1    0.000    0.000    0.019    0.019 excel.py:122(__init__)
#         1    0.000    0.000    0.001    0.001 excel.py:133(read_manifest)
#         1    0.000    0.000    0.191    0.191 excel.py:139(read_strings)
#         1    0.000    0.000    0.005    0.005 excel.py:147(read_workbook)
#         1    0.000    0.000    0.000    0.000 excel.py:170(read_properties)
#         1    0.000    0.000    0.000    0.000 excel.py:176(read_theme)
#         1    0.000    0.000    0.009    0.009 excel.py:203(read_worksheets)
#         1    0.000    0.000    0.210    0.210 excel.py:275(read)
#         1    0.000    0.000    0.229    0.229 excel.py:288(load_workbook)
#         4    0.000    0.000    0.000    0.000 excel.py:62(__init__)
#         1    0.000    0.000    0.019    0.019 excel.py:67(_validate_archive)
#         2    0.000    0.000    0.000    0.000 excel.py:72(__init__)
#         1    0.000    0.000    0.000    0.000 excel.py:99(__set__)
#         3    0.000    0.000    0.002    0.001 expressions.py:225(evaluate)
#         3    0.000    0.000    0.002    0.001 expressions.py:64(_evaluate_standard)
#         3    0.000    0.000    0.000    0.000 expressions.py:73(_can_use_numexpr)
#         3    0.000    0.000    0.002    0.001 expressions.py:93(_evaluate_numexpr)
#         6    0.000    0.000    0.003    0.001 extension.py:70(fget)
#         2    0.000    0.000    0.000    0.000 fills.py:57(from_tree)
#         2    0.000    0.000    0.000    0.000 fills.py:59(<listcomp>)
#         2    0.000    0.000    0.000    0.000 fills.py:84(__init__)
#         2    0.000    0.000    0.000    0.000 fills.py:96(_from_tree)
#         1    0.000    0.000    0.000    0.000 filters.py:321(__init__)
#        74    0.000    0.000    0.000    0.000 flags.py:49(__init__)
#        47    0.000    0.000    0.000    0.000 flags.py:53(allows_duplicate_labels)
#        46    0.000    0.000    0.000    0.000 flags.py:85(allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 flags.py:98(__getitem__)
#         2    0.000    0.000    0.001    0.000 fonts.py:101(from_tree)
#         2    0.000    0.000    0.000    0.000 fonts.py:27(_no_value)
#         2    0.000    0.000    0.000    0.000 fonts.py:69(__init__)
#         1    0.000    0.000    0.000    0.000 formatting.py:61(__init__)
#         1    0.000    0.000    0.070    0.070 frame.py:11664(values)
#        12    0.000    0.000    0.002    0.000 frame.py:12012(_reindex_for_setitem)
#        12    0.000    0.000    0.000    0.000 frame.py:1498(__len__)
#        13    0.000    0.000    0.002    0.000 frame.py:3703(_ixs)
#        16    0.000    0.000    0.016    0.001 frame.py:3758(__getitem__)
#         1    0.000    0.000    0.004    0.004 frame.py:3832(_getitem_bool_array)
#        12    0.000    0.000    0.020    0.002 frame.py:3955(__setitem__)
#         9    0.000    0.000    0.014    0.002 frame.py:4132(_iset_item_mgr)
#        12    0.000    0.000    0.017    0.001 frame.py:4139(_set_item_mgr)
#        12    0.000    0.000    0.020    0.002 frame.py:4164(_set_item)
#        12    0.000    0.000    0.000    0.000 frame.py:4234(_ensure_valid_index)
#        12    0.000    0.000    0.001    0.000 frame.py:4257(_box_col_values)
#        12    0.000    0.000    0.003    0.000 frame.py:4271(_clear_item_cache)
#        14    0.000    0.000    0.001    0.000 frame.py:4274(_get_item_cache)
#        12    0.000    0.000    0.003    0.000 frame.py:4892(_sanitize_column)
#         2    0.000    0.000    0.000    0.000 frame.py:600(_constructor)
#         3    0.000    0.000    0.013    0.004 frame.py:609(__init__)
#         1    0.000    0.000    0.000    0.000 frame.py:874(shape)
#         1    0.000    0.000    1.051    1.051 frame.py:9411(apply)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:1034(_argsort_dispatcher)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:1038(argsort)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:1777(_ravel_dispatcher)
#         6    0.000    0.000    0.000    0.000 fromnumeric.py:1781(ravel)
# ...
#   386/314    0.000    0.000    0.001    0.000 {built-in method builtins.hash}
# 972460/972399    0.179    0.000    0.209    0.000 {built-in method builtins.isinstance}
#       523    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 506274/505948    0.071    0.000    0.075    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#      1220    0.010    0.000    0.035    0.000 {built-in method builtins.max}
#       393    0.004    0.000    0.016    0.000 {built-in method builtins.min}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#        10    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#      3486    0.001    0.000    0.001    0.000 {built-in method builtins.setattr}
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#     19719    0.015    0.000    0.039    0.000 {built-in method builtins.sum}
#         3    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         1    0.000    0.000    0.000    0.000 {built-in method gc.get_referents}
#         3    0.073    0.024    0.073    0.024 {built-in method io.open}
#        23    0.000    0.000    0.000    0.000 {built-in method math.isinf}
#        23    0.000    0.000    0.000    0.000 {built-in method math.isnan}
#       288    0.000    0.000    0.000    0.000 {built-in method now}
#        37    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#         1    0.000    0.000    0.000    0.000 {built-in method nt.getcwd}
#        40    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#        10    0.077    0.008    0.077    0.008 {built-in method nt.stat}
#        17    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#        37    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#        36    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#   172/166    0.001    0.000    0.001    0.000 {built-in method numpy.asarray}
#   132/103    0.004    0.000    0.013    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        22    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.datetime_data}
#        79    0.008    0.000    0.008    0.000 {built-in method numpy.empty}
#        56    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#        28    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         3    0.008    0.003    0.008    0.003 {built-in method pandas._libs.lib.ensure_string_array}
#         5    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_datetime_array}
#        17    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#         3    0.003    0.001    0.003    0.001 {built-in method pandas._libs.missing.isnaobj}
#         3    0.002    0.001    0.042    0.014 {built-in method pandas._libs.tslib.array_to_datetime}
#         7    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.offsets.to_offset}
#         9    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.maybe_get_tz}
#         3    0.000    0.000    0.000    0.000 {built-in method pyexpat.ParserCreate}
#         3    0.000    0.000    0.000    0.000 {built-in method sys.intern}
#       833    0.007    0.000    0.007    0.000 {built-in method zlib.crc32}
#        10    0.000    0.000    0.000    0.000 {built-in method zlib.decompressobj}
#         6    0.000    0.000    0.000    0.000 {function DatetimeLikeArrayMixin.copy at 0x000002891CAF7380}
#        10    0.000    0.000    0.000    0.000 {function ZipExtFile.close at 0x0000028918C85EE0}
#       818    2.015    0.002    6.872    0.008 {method 'Parse' of 'pyexpat.xmlparser' objects}
#         8    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#       455    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         8    0.000    0.000    0.000    0.000 {method '_from_backing_data' of 'pandas._libs.arrays.NDArrayBacked' objects}
#         4    0.000    0.000    0.000    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#         3    0.000    0.000    0.000    0.000 {method '_set_freq' of 'pandas._libs.tslibs.timestamps._Timestamp' objects}
#         4    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         9    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#    726614    0.091    0.000    0.091    0.000 {method 'append' of 'collections.deque' objects}
#     31265    0.008    0.000    0.008    0.000 {method 'append' of 'list' objects}
#         8    0.000    0.000    0.000    0.000 {method 'append' of 'pandas._libs.internals.BlockPlacement' objects}
#         7    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#        18    0.002    0.000    0.002    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        12    0.003    0.000    0.003    0.000 {method 'clear' of 'dict' objects}
#      2881    0.001    0.000    0.001    0.000 {method 'clear' of 'xml.etree.ElementTree.Element' objects}
#         2    0.000    0.000    0.000    0.000 {method 'close' of '_io.BufferedReader' objects}
#         1    0.038    0.038    0.038    0.038 {method 'close' of '_io.BufferedWriter' objects}
#         2    0.000    0.000    0.000    0.000 {method 'close' of 'xml.etree.ElementTree.TreeBuilder' objects}
#         2    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#        26    0.003    0.000    0.003    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        36    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#       823    0.042    0.000    0.042    0.000 {method 'decompress' of 'zlib.Decompress' objects}
#         8    0.000    0.000    0.000    0.000 {method 'delete' of 'pandas._libs.internals.BlockPlacement' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#    726610    0.101    0.000    0.101    0.000 {method 'end' of 'xml.etree.ElementTree.TreeBuilder' objects}
#       154    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        26    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#         9    0.000    0.000    0.000    0.000 {method 'flush' of 'zlib.Decompress' objects}
#        24    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       424    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         5    0.002    0.000    0.002    0.000 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#     38878    0.037    0.000    0.037    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#      2977    0.001    0.000    0.001    0.000 {method 'group' of 're.Match' objects}
#         2    0.000    0.000    0.000    0.000 {method 'groupdict' of 're.Match' objects}
#         2    0.000    0.000    0.000    0.000 {method 'groups' of 're.Match' objects}
#        40    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#       576    0.000    0.000    0.000    0.000 {method 'is_finite' of 'decimal.Decimal' objects}
#      1440    0.000    0.000    0.000    0.000 {method 'isalpha' of 'str' objects}
#      2880    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#       576    0.000    0.000    0.000    0.000 {method 'isspace' of 'str' objects}
#        19    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         9    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#      2934    0.001    0.000    0.001    0.000 {method 'join' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#       310    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#      2962    0.004    0.000    0.004    0.000 {method 'match' of 're.Pattern' objects}
#         7    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'min' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#        24    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#       577    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#    725727    0.077    0.000    0.077    0.000 {method 'popleft' of 'collections.deque' objects}
#        11    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       422    0.046    0.000    0.046    0.000 {method 'read' of '_io.BufferedReader' objects}
#       104    0.000    0.000    0.000    0.000 {method 'read' of '_io.BytesIO' objects}
#      2592    0.001    0.000    0.001    0.000 {method 'read' of '_io.StringIO' objects}
#        33    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        37    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#       576    0.002    0.000    0.002    0.000 {method 'replace' of 'datetime.datetime' objects}
#      2901    0.001    0.000    0.001    0.000 {method 'replace' of 'str' objects}
#        15    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {method 'reshape' of 'pandas._libs.arrays.NDArrayBacked' objects}
#         4    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#        10    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#       141    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#        11    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#       426    0.001    0.000    0.001    0.000 {method 'seek' of '_io.BufferedReader' objects}
#        10    0.000    0.000    0.000    0.000 {method 'seekable' of '_io.BufferedReader' objects}
#        29    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#        66    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#    726613    0.664    0.000    0.664    0.000 {method 'start' of 'xml.etree.ElementTree.TreeBuilder' objects}
#         5    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#       294    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#     97135    0.014    0.000    0.014    0.000 {method 'strip' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#         4    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         4    0.001    0.000    0.001    0.000 {method 'take' of 'numpy.ndarray' objects}
#       417    0.003    0.000    0.003    0.000 {method 'tell' of '_io.BufferedReader' objects}
#         1    0.000    0.000    0.000    0.000 {method 'translate' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         2    0.001    0.000    0.001    0.000 {method 'unique' of 'pandas._libs.hashtable.Int64HashTable' objects}
#         1    0.001    0.001    0.001    0.001 {method 'unique' of 'pandas._libs.hashtable.StringHashTable' objects}
#         1    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'update' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.generic' objects}
#        18    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#       288    0.000    0.000    0.000    0.000 {method 'weekday' of 'datetime.date' objects}
#        40    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#        34    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_object}
#        19    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#         5    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_int64_int64}
#         2    0.001    0.000    0.001    0.000 {pandas._libs.algos.take_2d_axis0_int64_int64}
#         1    0.001    0.001    0.001    0.001 {pandas._libs.algos.take_2d_axis0_object_object}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis1_int64_int64}
#         1    0.001    0.001    0.001    0.001 {pandas._libs.algos.take_2d_axis1_object_object}
#         9    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.array_equivalent_object}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.dtypes_all_equal}
#        21    0.002    0.000    0.002    0.000 {pandas._libs.lib.infer_datetimelike_array}
#         7    0.001    0.000    0.001    0.000 {pandas._libs.lib.infer_dtype}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool_list}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#        25    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#     77754    0.013    0.000    0.013    0.000 {pandas._libs.lib.is_integer}
#        35    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#       214    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#     38933    0.008    0.000    0.008    0.000 {pandas._libs.lib.is_scalar}
#        25    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#         2    0.023    0.011    0.036    0.018 {pandas._libs.lib.map_infer_mask}
#         7    0.070    0.010    0.180    0.026 {pandas._libs.lib.map_infer}
#        11    0.006    0.001    0.007    0.001 {pandas._libs.lib.maybe_convert_numeric}
#        28    0.009    0.000    0.009    0.000 {pandas._libs.lib.maybe_convert_objects}
#         1    0.011    0.011    0.011    0.011 {pandas._libs.lib.to_object_array}
#         8    0.000    0.000    0.000    0.000 {pandas._libs.ops.maybe_convert_bool}
#        11    0.021    0.002    0.021    0.002 {pandas._libs.parsers.sanitize_objects}
#         2    0.002    0.001    0.002    0.001 {pandas._libs.tslibs.fields.get_date_field}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.fields.get_timedelta_field}
#         8    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.np_datetime.is_unitless}
#         4    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.np_datetime.py_get_unit_from_dtype}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.parsing.format_is_iso}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.parsing.try_parse_year_month_day}
#         1    0.066    0.066    0.066    0.066 {pandas._libs.tslibs.timedeltas.array_to_timedelta64}
#         1    0.063    0.063    0.063    0.063 {pandas._libs.tslibs.vectorized.ints_to_pydatetime}
